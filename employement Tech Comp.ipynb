# %% [markdown]
# Project Overview
#
# Dataset Description:
#
#     Source: The dataset provides a breakdown of employee demographics in key technology companies from 2014 to 2018.
#     Key Variables:
#         Gender: "female %", "male %"
#           Race: "Black %", "Asian %", "White %"
#     Scope: The dataset covers diversity data for tech companies over five years, focusing on cultural and gender diversity.

# %%
# import the neccessary python libraries and open the target data set 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# laoding of the data set
df = pd.read_csv(r'C:\Users\Neos\Desktop\DATA.A\Diversity in tech companies.csv')
df
# Out:
#     Year     Company  Female %  Male %  % White % Asian % Latino % Black  \
# 0   2018      Yahoo!        37      63       45      44        4       2
# 1   2018      Google        31      69       53      36        4       3
# 2   2018       Apple        32      68       54      21       13       9
# 3   2018       Cisco        24      76       53      37        5       4
# 4   2018        eBay        40      60       50      39        6       3
# ..   ...         ...       ...     ...      ...     ...      ...     ...
# 89  2014     Groupon        47      53       71      15        5       4
# 90  2014      Amazon        37      63       60      13        9      15
# 91  2014  Salesforce        29      71       67      22        4       2
# 92  2014     Pandora        49      51       71      12        7       3
# 93  2014   Microsoft        29      71       61      29        5       4
#
#    % Multi % Other % Undeclared
# 0        2       3            -
# ...

# %%
# a view of the last/ ending of the dataset just know the size of the dataset
df.tail()
# Out:
#     Year     Company  Female %  Male %  % White % Asian % Latino % Black  \
# 89  2014     Groupon        47      53       71      15        5       4
# 90  2014      Amazon        37      63       60      13        9      15
# 91  2014  Salesforce        29      71       67      22        4       2
# 92  2014     Pandora        49      51       71      12        7       3
# 93  2014   Microsoft        29      71       61      29        5       4
#
#    % Multi % Other % Undeclared
# 89       -       4            -
# 90       -       3            -
# 91       2       3            -
# 92       6       1            -
# 93       1       1            -

# %%
# code for information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          94 non-null     int64
#  1   Company       94 non-null     object
#  2   Female %      94 non-null     int64
#  3   Male %        94 non-null     int64
#  4   % White       94 non-null     int64
#  5   % Asian       94 non-null     object
#  6   % Latino      94 non-null     object
#  7   % Black       94 non-null     object
#  8   % Multi       94 non-null     object
#  9   % Other       93 non-null     object
#  10  % Undeclared  94 non-null     object
# dtypes: int64(4), object(7)
# memory usage: 8.2+ KB

# %%
# code to check for the missing values in the dataset
df.isnull().sum()
# Out:
# Year            0
# Company         0
# Female %        0
# Male %          0
# % White         0
# % Asian         0
# % Latino        0
# % Black         0
# % Multi         0
# % Other         1
# % Undeclared    0
# dtype: int64

# %%
# code for summary statistics of the dataset
df.describe()
# Out:
#               Year   Female %     Male %    % White
# count    94.000000  94.000000  94.000000  94.000000
# mean   2016.106383  35.234043  64.744681  59.393617
# std       1.432856   9.446426   9.464065   9.897559
# min    2014.000000  16.000000  46.000000  37.000000
# 25%    2015.000000  29.000000  57.250000  53.000000
# 50%    2016.000000  33.000000  67.000000  60.000000
# 75%    2017.000000  42.750000  71.000000  66.500000
# max    2018.000000  54.000000  84.000000  79.000000

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
# Female %
sns.histplot(df['Female %'], bins=10, kde=True)
plt.xlabel('Female %')
plt.ylabel('Companies')
plt.title('Distribution of Female Employees in Tech Companies')
plt.show()

# %% [markdown]
# Female %: "The histogram shows that most tech companies have around 25-30% female employees, indicating a concentration in this range"

# %%
# Male %
sns.histplot(df['Male %'], bins=10, kde=True)
plt.xlabel('Male %')
plt.ylabel('Number of Companies')
plt.title('Distribution of Male Employees in Tech Companies')
plt.show()

# %% [markdown]
# Male %: "The histogram shows that most tech companies have around 70-75 % male employees, indicating a concentration in this range"

# %%
# Black %
sns.histplot(df['% Black'], bins=10, kde=True)
plt.xlabel('Black %')
plt.ylabel('Number of Companies')
plt.title('Distribution of Black Employees in Tech Companies')
plt.show()

# %% [markdown]
# Black %: "The histogram shows that most tech companies have around 15-21% Black employees, indicating a concentration in this range"

# %%
# Asian %
sns.histplot(df['% Asian'], bins=10, kde=True)
plt.xlabel('% Asian')
plt.ylabel('Companies')
plt.title('Distribution of Asian Employees in Tech Companies')
plt.show()

# %%
# White %
sns.histplot(df['% White'], bins=10, kde=True)
plt.xlabel('% White')
plt.ylabel('Number of Companies')
plt.title('Distribution of White Employees in Tech Companies')
plt.show()

# %% [markdown]
# White %: "The histogram shows that most tech companies have around 50-60% white race employees, indicating a concentration in this range"

# %%
BIAVARIATE ANALYSIS

# %%
plt.figure(figsize=(14, 8))
sns.lineplot(data=df, x='Year', y='Female %', hue='Company', marker='o')

# Customize the plot
plt.xlabel('Year')
plt.ylabel('Female %')
plt.title('Percentage of Females Employed by Company Over Years')
plt.legend(title='Company', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(False)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Female % vs.Male %
sns.scatterplot(x='Female %', y='Male %', data=df)
plt.xlabel('Female %')
plt.ylabel('Male %')
plt.title('Female % vs Male %')
plt.show()

# %%
# Female % vs. Black %
sns.scatterplot(x='Female %', y='% Black', data=df)
plt.xlabel('Female %')
plt.ylabel('% Black')
plt.title('Female % vs. Black %')
plt.show()

# %%
#  % White vs. % Black
sns.scatterplot(x='% White', y='% Black', data=df)
plt.xlabel(' % White')
plt.ylabel(' % Black')
plt.title('White % vs. Black %')
plt.show()

# %%
# White % vs. Asian %
sns.scatterplot(x='% White', y='% Asian', data=df)
plt.xlabel('% White')
plt.ylabel('% Asian')
plt.title('White % vs.Asian %')
plt.show()

# %%
# White % vs. Asian %
sns.scatterplot(x='% Black', y='% Asian', data=df)
plt.xlabel('% Black')
plt.ylabel('% Asian')
plt.title('Black % vs.Asian %')
plt.show()

# %%
sns.scatterplot(x='Year', y='Female %', data=df)
plt.show()

# %%
sns.scatterplot(x='Year', y='Male %', data=df)
plt.show()

# %%
sns.scatterplot(x='Year', y='Male %', data=df)
plt.show()

# %%
sns.scatterplot(x='Year', y='% Asian', data=df)
plt.show()

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
sns.pairplot(df[['Female %', '% Black', '% Asian', '% White']])
plt.suptitle('Pair Plot of Diversity Metrics', y=1.02)
plt.show()
